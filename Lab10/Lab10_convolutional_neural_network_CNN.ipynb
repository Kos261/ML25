# %% [markdown]
# # Lab 10 - Convolutional Neural Network, CNN
#
# ### Author: Szymon Nowakowski

# %% [markdown]
# # Presentation on Convolutional Layers
# --------------------
#
# We shall start off by going through a [short presentation on convolusional layers](https://github.com/SzymonNowakowski/Machine-Learning-2024/blob/master/convolutional_layers.pdf). It is best to first download it and then go through it in a slide-show layout.

# %% [markdown]
# # Reading MNIST Dataset
# ----------------------------------

# %%
import torch
import torchvision
from matplotlib import pyplot

transform = torchvision.transforms.Compose(
    [ torchvision.transforms.ToTensor(), #Converts a PIL Image or numpy.ndarray (H x W x C) in the range [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0]
      torchvision.transforms.Normalize((0.1307), (0.3081))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=2048,
                                          shuffle=True)   #we do shuffle it to give more randomizations to training epochs

testset = torchvision.datasets.MNIST(root='./data',
                                     train=False,
                                     download=True,
                                     transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=1,
                                         shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %% [markdown]
# # Tensor Sizes
# -------------------
#
# Recall:
# - Batched labels are of order one. The first (and only) index is a sample index within a batch.
# - Image batches have order 4. The first order is a batch order, but a second order has dimensionality of 1 and thus it can be indexed by 0 only.
#   - This index represents a Channel number inserted here by `ToTensor()` transformation, always 0.
#   - This singleton order should be retained because we want to use convolutional layers, which explicitly require this order. For RGB images we have 3 channels, for B&W images we have only one channel.

# %% [markdown]
# # CNN Definition
# -----------------

# %% [markdown]
# ## Task
#
# Your job now is to code the definition of the LeNet5 neural network. You can find the definition [here](https://en.wikipedia.org/wiki/LeNet#/media/File:Comparison_image_neural_networks.svg).

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet5(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=2)  # z 28x28 -> 28x28
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0) # z 14x14 -> 10x10
        self.conv3 = torch.nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5, padding=0) # z 5x5 -> 1x1
        self.relu = torch.nn.ReLU()
        self.pool = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.flat = torch.nn.Flatten()
        self.dropout = torch.nn.Dropout(0.05)
        self.dense1 = torch.nn.Linear(in_features=120, out_features=84)
        self.dense2 = torch.nn.Linear(in_features=84, out_features=10)

    def forward(self, x):
        # B,1,28,28
        x = self.relu(self.conv1(x))    # B,6,28,28
        x = self.pool(x)                # B,6,14,14
        x = self.relu(self.conv2(x))    # B,16,10,10
        x = self.pool(x)                # B,16,5,5
        x = self.relu(self.conv3(x))    # B,120,1,1
        x = x.squeeze(-1).squeeze(-1)   # B,120
        x = self.relu(self.dense1(x))   # B,84
        x = self.dropout(x)
        x = self.dense2(x)              # B,10
        return x

# %% [markdown]
# # Training Loop
# ----------------------

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Working on {device}")

net = LeNet5().to(device)
optimizer = torch.optim.Adam(net.parameters(), 0.001)   #initial and fixed learning rate of 0.001.

net.train()    #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing traning
for epoch in range(16):  #  an epoch is a training run through the whole data set

    for batch, data in enumerate(trainloader):
        batch_inputs, batch_labels = data

        batch_inputs = batch_inputs.to(device)  #explicitly moving the data to the target device
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()

        batch_outputs = net(batch_inputs)   #this line calls the forward(self, x) method of the LeNet5 object. Please note,
                                            # the nonlinear activation after the last layer is NOT applied
        loss = torch.nn.functional.cross_entropy(batch_outputs, batch_labels, reduction = "mean") #instead, nonlinear softmax is applied internally in THIS loss function
        print("epoch:", epoch, "batch:", batch, "current batch loss:", loss.item())
        loss.backward()       #this computes gradients as we have seen in previous workshops
        optimizer.step()     #but this line in fact updates our neural network.
                                ####You can experiment - comment this line and check, that the loss DOE
# Out:
# Working on cuda
# epoch: 0 batch: 0 current batch loss: 2.310398578643799
# epoch: 0 batch: 1 current batch loss: 2.300342082977295
# epoch: 0 batch: 2 current batch loss: 2.296511173248291
# epoch: 0 batch: 3 current batch loss: 2.2860493659973145
# epoch: 0 batch: 4 current batch loss: 2.275360584259033
# epoch: 0 batch: 5 current batch loss: 2.261397123336792
# epoch: 0 batch: 6 current batch loss: 2.2442708015441895
# epoch: 0 batch: 7 current batch loss: 2.2241880893707275
# epoch: 0 batch: 8 current batch loss: 2.196636915206909
# epoch: 0 batch: 9 current batch loss: 2.1646013259887695
# epoch: 0 batch: 10 current batch loss: 2.1226086616516113
# epoch: 0 batch: 11 current batch loss: 2.084047794342041
# epoch: 0 batch: 12 current batch loss: 2.0250794887542725
# epoch: 0 batch: 13 current batch loss: 1.9624018669128418
# epoch: 0 batch: 14 current batch loss: 1.8885951042175293
# epoch: 0 batch: 15 current batch loss: 1.8174701929092407
# epoch: 0 batch: 16 current batch loss: 1.7210159301757812
# epoch: 0 batch: 17 current batch loss: 1.6359368562698364
# epoch: 0 batch: 18 current batch loss: 1.5161675214767456
# epoch: 0 batch: 19 current batch loss: 1.4105350971221924
# epoch: 0 batch: 20 current batch loss: 1.3120207786560059
# epoch: 0 batch: 21 current batch loss: 1.209964632987976
# epoch: 0 batch: 22 current batch loss: 1.124955415725708
# epoch: 0 batch: 23 current batch loss: 1.013805866241455
# epoch: 0 batch: 24 current batch loss: 0.9651603698730469
# epoch: 0 batch: 25 current batch loss: 0.9015833139419556
# epoch: 0 batch: 26 current batch loss: 0.7951095104217529
# epoch: 0 batch: 27 current batch loss: 0.7536740303039551
# epoch: 0 batch: 28 current batch loss: 0.7543565630912781
# epoch: 0 batch: 29 current batch loss: 0.6587799191474915
# epoch: 1 batch: 0 current batch loss: 0.6555148363113403
# epoch: 1 batch: 1 current batch loss: 0.674340546131134
# epoch: 1 batch: 2 current batch loss: 0.6417936682701111
# epoch: 1 batch: 3 current batch loss: 0.6079431176185608
# epoch: 1 batch: 4 current batch loss: 0.6420363187789917
# epoch: 1 batch: 5 current batch loss: 0.5876516699790955
# epoch: 1 batch: 6 current batch loss: 0.5889431834220886
# epoch: 1 batch: 7 current batch loss: 0.5203374624252319
# epoch: 1 batch: 8 current batch loss: 0.6014924049377441
# epoch: 1 batch: 9 current batch loss: 0.5863141417503357
# epoch: 1 batch: 10 current batch loss: 0.5631696581840515
# epoch: 1 batch: 11 current batch loss: 0.5548832416534424
# epoch: 1 batch: 12 current batch loss: 0.5579567551612854
# epoch: 1 batch: 13 current batch loss: 0.505313515663147
# epoch: 1 batch: 14 current batch loss: 0.46288323402404785
# epoch: 1 batch: 15 current batch loss: 0.5382884740829468
# epoch: 1 batch: 16 current batch loss: 0.47293826937675476
# epoch: 1 batch: 17 current batch loss: 0.5167955756187439
# epoch: 1 batch: 18 current batch loss: 0.4522002339363098
# epoch: 1 batch: 19 current batch loss: 0.48512765765190125
# epoch: 1 batch: 20 current batch loss: 0.4292675852775574
# epoch: 1 batch: 21 current batch loss: 0.3887471556663513
# epoch: 1 batch: 22 current batch loss: 0.4429612159729004
# epoch: 1 batch: 23 current batch loss: 0.41870513558387756
# epoch: 1 batch: 24 current batch loss: 0.45374852418899536
# epoch: 1 batch: 25 current batch loss: 0.40585070848464966
# epoch: 1 batch: 26 current batch loss: 0.3761368989944458
# epoch: 1 batch: 27 current batch loss: 0.42597898840904236
# epoch: 1 batch: 28 current batch loss: 0.403277724981308
# epoch: 1 batch: 29 current batch loss: 0.3700905740261078
# epoch: 2 batch: 0 current batch loss: 0.42347896099090576
# epoch: 2 batch: 1 current batch loss: 0.3793832063674927
# epoch: 2 batch: 2 current batch loss: 0.37465178966522217
# epoch: 2 batch: 3 current batch loss: 0.40471208095550537
# epoch: 2 batch: 4 current batch loss: 0.36774343252182007
# epoch: 2 batch: 5 current batch loss: 0.3914950489997864
# epoch: 2 batch: 6 current batch loss: 0.3477443754673004
# epoch: 2 batch: 7 current batch loss: 0.3721633553504944
# epoch: 2 batch: 8 current batch loss: 0.36468613147735596
# epoch: 2 batch: 9 current batch loss: 0.32211625576019287
# epoch: 2 batch: 10 current batch loss: 0.3418006896972656
# epoch: 2 batch: 11 current batch loss: 0.36790409684181213
# epoch: 2 batch: 12 current batch loss: 0.35478246212005615
# epoch: 2 batch: 13 current batch loss: 0.33377715945243835
# epoch: 2 batch: 14 current batch loss: 0.32304391264915466
# epoch: 2 batch: 15 current batch loss: 0.3433035612106323
# epoch: 2 batch: 16 current batch loss: 0.34559717774391174
# epoch: 2 batch: 17 current batch loss: 0.34614798426628113
# epoch: 2 batch: 18 current batch loss: 0.31944045424461365
# epoch: 2 batch: 19 current batch loss: 0.3045828342437744
# epoch: 2 batch: 20 current batch loss: 0.3194054067134857
# epoch: 2 batch: 21 current batch loss: 0.3349982500076294
# epoch: 2 batch: 22 current batch loss: 0.32605987787246704
# epoch: 2 batch: 23 current batch loss: 0.2963598668575287
# epoch: 2 batch: 24 current batch loss: 0.2956005930900574
# epoch: 2 batch: 25 current batch loss: 0.3083689212799072
# epoch: 2 batch: 26 current batch loss: 0.3528001308441162
# epoch: 2 batch: 27 current batch loss: 0.2929301857948303
# epoch: 2 batch: 28 current batch loss: 0.3111896514892578
# epoch: 2 batch: 29 current batch loss: 0.3105713129043579
# epoch: 3 batch: 0 current batch loss: 0.3053337335586548
# epoch: 3 batch: 1 current batch loss: 0.334570974111557
# epoch: 3 batch: 2 current batch loss: 0.28666141629219055
# epoch: 3 batch: 3 current batch loss: 0.2877606451511383
# epoch: 3 batch: 4 current batch loss: 0.28694888949394226
# epoch: 3 batch: 5 current batch loss: 0.2853473126888275
# epoch: 3 batch: 6 current batch loss: 0.27508723735809326
# epoch: 3 batch: 7 current batch loss: 0.2660224437713623
# epoch: 3 batch: 8 current batch loss: 0.2610544264316559
# epoch: 3 batch: 9 current batch loss: 0.31183066964149475
# epoch: 3 batch: 10 current batch loss: 0.26086854934692383
# epoch: 3 batch: 11 current batch loss: 0.26583099365234375
# epoch: 3 batch: 12 current batch loss: 0.27105027437210083
# epoch: 3 batch: 13 current batch loss: 0.2786092758178711
# epoch: 3 batch: 14 current batch loss: 0.26861372590065
# epoch: 3 batch: 15 current batch loss: 0.27391061186790466
# epoch: 3 batch: 16 current batch loss: 0.2786296606063843
# epoch: 3 batch: 17 current batch loss: 0.24131067097187042
# epoch: 3 batch: 18 current batch loss: 0.2710950970649719
# epoch: 3 batch: 19 current batch loss: 0.26500481367111206
# epoch: 3 batch: 20 current batch loss: 0.2316889464855194
# epoch: 3 batch: 21 current batch loss: 0.24863173067569733
# epoch: 3 batch: 22 current batch loss: 0.2491816133260727
# epoch: 3 batch: 23 current batch loss: 0.24604570865631104
# epoch: 3 batch: 24 current batch loss: 0.28402721881866455
# epoch: 3 batch: 25 current batch loss: 0.206503227353096
# epoch: 3 batch: 26 current batch loss: 0.23890641331672668
# epoch: 3 batch: 27 current batch loss: 0.2591058909893036
# epoch: 3 batch: 28 current batch loss: 0.23634357750415802
# epoch: 3 batch: 29 current batch loss: 0.22870151698589325
# epoch: 4 batch: 0 current batch loss: 0.24473196268081665
# epoch: 4 batch: 1 current batch loss: 0.24148431420326233
# epoch: 4 batch: 2 current batch loss: 0.20361573994159698
# epoch: 4 batch: 3 current batch loss: 0.23231668770313263
# epoch: 4 batch: 4 current batch loss: 0.2705790400505066
# epoch: 4 batch: 5 current batch loss: 0.2139405608177185
# epoch: 4 batch: 6 current batch loss: 0.22652150690555573
# epoch: 4 batch: 7 current batch loss: 0.225752055644989
# epoch: 4 batch: 8 current batch loss: 0.24378031492233276
# epoch: 4 batch: 9 current batch loss: 0.21752019226551056
# epoch: 4 batch: 10 current batch loss: 0.212954580783844
# epoch: 4 batch: 11 current batch loss: 0.2217566967010498
# epoch: 4 batch: 12 current batch loss: 0.20114082098007202
# epoch: 4 batch: 13 current batch loss: 0.211390882730484
# epoch: 4 batch: 14 current batch loss: 0.1974974423646927
# epoch: 4 batch: 15 current batch loss: 0.17808201909065247
# epoch: 4 batch: 16 current batch loss: 0.19227010011672974
# epoch: 4 batch: 17 current batch loss: 0.21411627531051636
# epoch: 4 batch: 18 current batch loss: 0.19050228595733643
# epoch: 4 batch: 19 current batch loss: 0.2050088346004486
# epoch: 4 batch: 20 current batch loss: 0.2304162085056305
# epoch: 4 batch: 21 current batch loss: 0.235804483294487
# epoch: 4 batch: 22 current batch loss: 0.21888165175914764
# epoch: 4 batch: 23 current batch loss: 0.2134992927312851
# epoch: 4 batch: 24 current batch loss: 0.19939059019088745
# epoch: 4 batch: 25 current batch loss: 0.19697313010692596
# epoch: 4 batch: 26 current batch loss: 0.18559099733829498
# epoch: 4 batch: 27 current batch loss: 0.2069002389907837
# epoch: 4 batch: 28 current batch loss: 0.187162384390831
# epoch: 4 batch: 29 current batch loss: 0.19583041965961456
# epoch: 5 batch: 0 current batch loss: 0.16960598528385162
# epoch: 5 batch: 1 current batch loss: 0.18809790909290314
# epoch: 5 batch: 2 current batch loss: 0.1830114871263504
# epoch: 5 batch: 3 current batch loss: 0.17687781155109406
# epoch: 5 batch: 4 current batch loss: 0.21282926201820374
# epoch: 5 batch: 5 current batch loss: 0.175727978348732
# epoch: 5 batch: 6 current batch loss: 0.19018447399139404
# epoch: 5 batch: 7 current batch loss: 0.1765388399362564
# epoch: 5 batch: 8 current batch loss: 0.20190754532814026
# epoch: 5 batch: 9 current batch loss: 0.1848902851343155
# epoch: 5 batch: 10 current batch loss: 0.17622095346450806
# epoch: 5 batch: 11 current batch loss: 0.18381111323833466
# epoch: 5 batch: 12 current batch loss: 0.17029549181461334
# epoch: 5 batch: 13 current batch loss: 0.17650143802165985
# epoch: 5 batch: 14 current batch loss: 0.15608015656471252
# epoch: 5 batch: 15 current batch loss: 0.19166068732738495
# epoch: 5 batch: 16 current batch loss: 0.1831153929233551
# epoch: 5 batch: 17 current batch loss: 0.15872623026371002
# epoch: 5 batch: 18 current batch loss: 0.1700199991464615
# epoch: 5 batch: 19 current batch loss: 0.17033877968788147
# epoch: 5 batch: 20 current batch loss: 0.17937321960926056
# epoch: 5 batch: 21 current batch loss: 0.16708755493164062
# epoch: 5 batch: 22 current batch loss: 0.1850663274526596
# epoch: 5 batch: 23 current batch loss: 0.18312694132328033
# epoch: 5 batch: 24 current batch loss: 0.16588366031646729
# epoch: 5 batch: 25 current batch loss: 0.15761494636535645
# epoch: 5 batch: 26 current batch loss: 0.16830413043498993
# epoch: 5 batch: 27 current batch loss: 0.1636338084936142
# epoch: 5 batch: 28 current batch loss: 0.15358537435531616
# epoch: 5 batch: 29 current batch loss: 0.1493394374847412
# epoch: 6 batch: 0 current batch loss: 0.15075217187404633
# epoch: 6 batch: 1 current batch loss: 0.17518724501132965
# epoch: 6 batch: 2 current batch loss: 0.15424175560474396
# epoch: 6 batch: 3 current batch loss: 0.1461365669965744
# epoch: 6 batch: 4 current batch loss: 0.17110809683799744
# epoch: 6 batch: 5 current batch loss: 0.1588679552078247
# epoch: 6 batch: 6 current batch loss: 0.1369427591562271
# epoch: 6 batch: 7 current batch loss: 0.15818870067596436
# epoch: 6 batch: 8 current batch loss: 0.1781623214483261
# epoch: 6 batch: 9 current batch loss: 0.16424483060836792
# epoch: 6 batch: 10 current batch loss: 0.15474720299243927
# epoch: 6 batch: 11 current batch loss: 0.16241376101970673
# epoch: 6 batch: 12 current batch loss: 0.1519147753715515
# epoch: 6 batch: 13 current batch loss: 0.15235920250415802
# epoch: 6 batch: 14 current batch loss: 0.16507671773433685
# epoch: 6 batch: 15 current batch loss: 0.1470603197813034
# epoch: 6 batch: 16 current batch loss: 0.15649272501468658
# epoch: 6 batch: 17 current batch loss: 0.1418183147907257
# epoch: 6 batch: 18 current batch loss: 0.14204749464988708
# epoch: 6 batch: 19 current batch loss: 0.14588917791843414
# epoch: 6 batch: 20 current batch loss: 0.1573943793773651
# epoch: 6 batch: 21 current batch loss: 0.1342620998620987
# epoch: 6 batch: 22 current batch loss: 0.139229416847229
# epoch: 6 batch: 23 current batch loss: 0.1455361396074295
# epoch: 6 batch: 24 current batch loss: 0.1546105146408081
# epoch: 6 batch: 25 current batch loss: 0.13312602043151855
# epoch: 6 batch: 26 current batch loss: 0.11651777476072311
# epoch: 6 batch: 27 current batch loss: 0.13185176253318787
# epoch: 6 batch: 28 current batch loss: 0.13743990659713745
# epoch: 6 batch: 29 current batch loss: 0.10924810916185379
# epoch: 7 batch: 0 current batch loss: 0.1306084841489792
# epoch: 7 batch: 1 current batch loss: 0.12705108523368835
# epoch: 7 batch: 2 current batch loss: 0.12349016964435577
# epoch: 7 batch: 3 current batch loss: 0.13515183329582214
# epoch: 7 batch: 4 current batch loss: 0.13996544480323792
# epoch: 7 batch: 5 current batch loss: 0.14143848419189453
# epoch: 7 batch: 6 current batch loss: 0.13747085630893707
# epoch: 7 batch: 7 current batch loss: 0.1556234210729599
# epoch: 7 batch: 8 current batch loss: 0.12036742269992828
# epoch: 7 batch: 9 current batch loss: 0.14196190237998962
# epoch: 7 batch: 10 current batch loss: 0.12659555673599243
# epoch: 7 batch: 11 current batch loss: 0.12636098265647888
# epoch: 7 batch: 12 current batch loss: 0.11370676755905151
# epoch: 7 batch: 13 current batch loss: 0.13264039158821106
# epoch: 7 batch: 14 current batch loss: 0.11383219808340073
# epoch: 7 batch: 15 current batch loss: 0.12519536912441254
# epoch: 7 batch: 16 current batch loss: 0.12541954219341278
# epoch: 7 batch: 17 current batch loss: 0.12273827195167542
# epoch: 7 batch: 18 current batch loss: 0.13108029961585999
# epoch: 7 batch: 19 current batch loss: 0.1157480999827385
# epoch: 7 batch: 20 current batch loss: 0.11959977447986603
# epoch: 7 batch: 21 current batch loss: 0.11831450462341309
# epoch: 7 batch: 22 current batch loss: 0.11675198376178741
# epoch: 7 batch: 23 current batch loss: 0.12244182825088501
# epoch: 7 batch: 24 current batch loss: 0.1215280145406723
# epoch: 7 batch: 25 current batch loss: 0.12821334600448608
# epoch: 7 batch: 26 current batch loss: 0.1308748722076416
# epoch: 7 batch: 27 current batch loss: 0.11752413958311081
# epoch: 7 batch: 28 current batch loss: 0.12689661979675293
# epoch: 7 batch: 29 current batch loss: 0.12458871304988861
# epoch: 8 batch: 0 current batch loss: 0.12966960668563843
# epoch: 8 batch: 1 current batch loss: 0.10597709566354752
# epoch: 8 batch: 2 current batch loss: 0.1392521858215332
# epoch: 8 batch: 3 current batch loss: 0.10903045535087585
# epoch: 8 batch: 4 current batch loss: 0.10522925853729248
# epoch: 8 batch: 5 current batch loss: 0.11522623896598816
# epoch: 8 batch: 6 current batch loss: 0.13691765069961548
# epoch: 8 batch: 7 current batch loss: 0.10628532618284225
# epoch: 8 batch: 8 current batch loss: 0.10688242316246033
# epoch: 8 batch: 9 current batch loss: 0.10704314708709717
# epoch: 8 batch: 10 current batch loss: 0.12081881612539291
# epoch: 8 batch: 11 current batch loss: 0.10275562107563019
# epoch: 8 batch: 12 current batch loss: 0.1290273368358612
# epoch: 8 batch: 13 current batch loss: 0.09885253012180328
# epoch: 8 batch: 14 current batch loss: 0.11053534597158432
# epoch: 8 batch: 15 current batch loss: 0.13437645137310028
# epoch: 8 batch: 16 current batch loss: 0.1168074905872345
# epoch: 8 batch: 17 current batch loss: 0.11740966886281967
# epoch: 8 batch: 18 current batch loss: 0.12077957391738892
# epoch: 8 batch: 19 current batch loss: 0.12890514731407166
# epoch: 8 batch: 20 current batch loss: 0.11839872598648071
# epoch: 8 batch: 21 current batch loss: 0.12027489393949509
# epoch: 8 batch: 22 current batch loss: 0.13361477851867676
# epoch: 8 batch: 23 current batch loss: 0.1143985241651535
# epoch: 8 batch: 24 current batch loss: 0.11376215517520905
# epoch: 8 batch: 25 current batch loss: 0.11191146075725555
# epoch: 8 batch: 26 current batch loss: 0.1164996325969696
# epoch: 8 batch: 27 current batch loss: 0.10804671794176102
# epoch: 8 batch: 28 current batch loss: 0.09871180355548859
# epoch: 8 batch: 29 current batch loss: 0.08090870082378387
# epoch: 9 batch: 0 current batch loss: 0.11634685844182968
# epoch: 9 batch: 1 current batch loss: 0.10061570256948471
# epoch: 9 batch: 2 current batch loss: 0.09961427003145218
# epoch: 9 batch: 3 current batch loss: 0.09828557074069977
# epoch: 9 batch: 4 current batch loss: 0.100057452917099
# epoch: 9 batch: 5 current batch loss: 0.10678784549236298
# epoch: 9 batch: 6 current batch loss: 0.09693755954504013
# epoch: 9 batch: 7 current batch loss: 0.10010821372270584
# epoch: 9 batch: 8 current batch loss: 0.11662837117910385
# epoch: 9 batch: 9 current batch loss: 0.08753702044487
# epoch: 9 batch: 10 current batch loss: 0.0904024988412857
# epoch: 9 batch: 11 current batch loss: 0.07996159046888351
# epoch: 9 batch: 12 current batch loss: 0.10226152837276459
# epoch: 9 batch: 13 current batch loss: 0.09477455914020538
# epoch: 9 batch: 14 current batch loss: 0.09554578363895416
# epoch: 9 batch: 15 current batch loss: 0.1014496237039566
# epoch: 9 batch: 16 current batch loss: 0.09063770622015
# epoch: 9 batch: 17 current batch loss: 0.10916750133037567
# epoch: 9 batch: 18 current batch loss: 0.11561409384012222
# epoch: 9 batch: 19 current batch loss: 0.09910240024328232
# epoch: 9 batch: 20 current batch loss: 0.09373759478330612
# epoch: 9 batch: 21 current batch loss: 0.10628870874643326
# epoch: 9 batch: 22 current batch loss: 0.09541727602481842
# epoch: 9 batch: 23 current batch loss: 0.09269528090953827
# epoch: 9 batch: 24 current batch loss: 0.10836400836706161
# epoch: 9 batch: 25 current batch loss: 0.11067700386047363
# epoch: 9 batch: 26 current batch loss: 0.08335611969232559
# epoch: 9 batch: 27 current batch loss: 0.10838133841753006
# epoch: 9 batch: 28 current batch loss: 0.1128678247332573
# epoch: 9 batch: 29 current batch loss: 0.0942598357796669
# epoch: 10 batch: 0 current batch loss: 0.08454656600952148
# epoch: 10 batch: 1 current batch loss: 0.08885583281517029
# epoch: 10 batch: 2 current batch loss: 0.10216236114501953
# epoch: 10 batch: 3 current batch loss: 0.10649002343416214
# epoch: 10 batch: 4 current batch loss: 0.09781016409397125
# epoch: 10 batch: 5 current batch loss: 0.09760633111000061
# epoch: 10 batch: 6 current batch loss: 0.11940018087625504
# epoch: 10 batch: 7 current batch loss: 0.08635541796684265
# epoch: 10 batch: 8 current batch loss: 0.0851508304476738
# epoch: 10 batch: 9 current batch loss: 0.11433053761720657
# epoch: 10 batch: 10 current batch loss: 0.08409948647022247
# epoch: 10 batch: 11 current batch loss: 0.08776573836803436
# epoch: 10 batch: 12 current batch loss: 0.09211724251508713
# epoch: 10 batch: 13 current batch loss: 0.07763003557920456
# epoch: 10 batch: 14 current batch loss: 0.07257270812988281
# epoch: 10 batch: 15 current batch loss: 0.0879187285900116
# epoch: 10 batch: 16 current batch loss: 0.08534324169158936
# epoch: 10 batch: 17 current batch loss: 0.08537434786558151
# epoch: 10 batch: 18 current batch loss: 0.09442806243896484
# epoch: 10 batch: 19 current batch loss: 0.08496905863285065
# epoch: 10 batch: 20 current batch loss: 0.10178318619728088
# epoch: 10 batch: 21 current batch loss: 0.07922594994306564
# epoch: 10 batch: 22 current batch loss: 0.10020187497138977
# epoch: 10 batch: 23 current batch loss: 0.08637642860412598
# epoch: 10 batch: 24 current batch loss: 0.09850910305976868
# epoch: 10 batch: 25 current batch loss: 0.07457132637500763
# epoch: 10 batch: 26 current batch loss: 0.08458181470632553
# epoch: 10 batch: 27 current batch loss: 0.08657202124595642
# epoch: 10 batch: 28 current batch loss: 0.08464629203081131
# epoch: 10 batch: 29 current batch loss: 0.08262830972671509
# epoch: 11 batch: 0 current batch loss: 0.09713756293058395
# epoch: 11 batch: 1 current batch loss: 0.08385611325502396
# epoch: 11 batch: 2 current batch loss: 0.09769931435585022
# epoch: 11 batch: 3 current batch loss: 0.07251078635454178
# epoch: 11 batch: 4 current batch loss: 0.09237849712371826
# epoch: 11 batch: 5 current batch loss: 0.08556017279624939
# epoch: 11 batch: 6 current batch loss: 0.08533123880624771
# epoch: 11 batch: 7 current batch loss: 0.09410170465707779
# epoch: 11 batch: 8 current batch loss: 0.08151170611381531
# epoch: 11 batch: 9 current batch loss: 0.09171344339847565
# epoch: 11 batch: 10 current batch loss: 0.08764541894197464
# epoch: 11 batch: 11 current batch loss: 0.07896193116903305
# epoch: 11 batch: 12 current batch loss: 0.08326055854558945
# epoch: 11 batch: 13 current batch loss: 0.10403714329004288
# epoch: 11 batch: 14 current batch loss: 0.07859981060028076
# epoch: 11 batch: 15 current batch loss: 0.0813816711306572
# epoch: 11 batch: 16 current batch loss: 0.10093852132558823
# epoch: 11 batch: 17 current batch loss: 0.10075991600751877
# epoch: 11 batch: 18 current batch loss: 0.06726793944835663
# epoch: 11 batch: 19 current batch loss: 0.08039430528879166
# epoch: 11 batch: 20 current batch loss: 0.07263913750648499
# epoch: 11 batch: 21 current batch loss: 0.07671590894460678
# epoch: 11 batch: 22 current batch loss: 0.07872144132852554
# epoch: 11 batch: 23 current batch loss: 0.08572498708963394
# epoch: 11 batch: 24 current batch loss: 0.0872819796204567
# epoch: 11 batch: 25 current batch loss: 0.06964946538209915
# epoch: 11 batch: 26 current batch loss: 0.08086585253477097
# epoch: 11 batch: 27 current batch loss: 0.09827139228582382
# epoch: 11 batch: 28 current batch loss: 0.07985608279705048
# epoch: 11 batch: 29 current batch loss: 0.07592038810253143
# epoch: 12 batch: 0 current batch loss: 0.07675479352474213
# epoch: 12 batch: 1 current batch loss: 0.08412209898233414
# epoch: 12 batch: 2 current batch loss: 0.0744699165225029
# epoch: 12 batch: 3 current batch loss: 0.07535767555236816
# epoch: 12 batch: 4 current batch loss: 0.09342371672391891
# epoch: 12 batch: 5 current batch loss: 0.07864309102296829
# epoch: 12 batch: 6 current batch loss: 0.09434336423873901
# epoch: 12 batch: 7 current batch loss: 0.08104708045721054
# epoch: 12 batch: 8 current batch loss: 0.07790753990411758
# epoch: 12 batch: 9 current batch loss: 0.08265195786952972
# epoch: 12 batch: 10 current batch loss: 0.0769844502210617
# epoch: 12 batch: 11 current batch loss: 0.0657184049487114
# epoch: 12 batch: 12 current batch loss: 0.07888563722372055
# epoch: 12 batch: 13 current batch loss: 0.0655069351196289
# epoch: 12 batch: 14 current batch loss: 0.08664990216493607
# epoch: 12 batch: 15 current batch loss: 0.0744398683309555
# epoch: 12 batch: 16 current batch loss: 0.07342914491891861
# epoch: 12 batch: 17 current batch loss: 0.09278655052185059
# epoch: 12 batch: 18 current batch loss: 0.07198965549468994
# epoch: 12 batch: 19 current batch loss: 0.06752464920282364
# epoch: 12 batch: 20 current batch loss: 0.08242671936750412
# epoch: 12 batch: 21 current batch loss: 0.08277356624603271
# epoch: 12 batch: 22 current batch loss: 0.08651973307132721
# epoch: 12 batch: 23 current batch loss: 0.06523266434669495
# epoch: 12 batch: 24 current batch loss: 0.06792134791612625
# epoch: 12 batch: 25 current batch loss: 0.0601881705224514
# epoch: 12 batch: 26 current batch loss: 0.07649082690477371
# epoch: 12 batch: 27 current batch loss: 0.07749269902706146
# epoch: 12 batch: 28 current batch loss: 0.07436076551675797
# epoch: 12 batch: 29 current batch loss: 0.09980285167694092
# epoch: 13 batch: 0 current batch loss: 0.07837801426649094
# epoch: 13 batch: 1 current batch loss: 0.06997127830982208
# epoch: 13 batch: 2 current batch loss: 0.07903725653886795
# epoch: 13 batch: 3 current batch loss: 0.07065453380346298
# epoch: 13 batch: 4 current batch loss: 0.05763394013047218
# epoch: 13 batch: 5 current batch loss: 0.07285473495721817
# epoch: 13 batch: 6 current batch loss: 0.06750795245170593
# epoch: 13 batch: 7 current batch loss: 0.07610758394002914
# epoch: 13 batch: 8 current batch loss: 0.08506617695093155
# epoch: 13 batch: 9 current batch loss: 0.08906606584787369
# epoch: 13 batch: 10 current batch loss: 0.08257213234901428
# epoch: 13 batch: 11 current batch loss: 0.09927727282047272
# epoch: 13 batch: 12 current batch loss: 0.07173170149326324
# epoch: 13 batch: 13 current batch loss: 0.0811031311750412
# epoch: 13 batch: 14 current batch loss: 0.06722415238618851
# epoch: 13 batch: 15 current batch loss: 0.07395250350236893
# epoch: 13 batch: 16 current batch loss: 0.07830590754747391
# epoch: 13 batch: 17 current batch loss: 0.06934764236211777
# epoch: 13 batch: 18 current batch loss: 0.08276088535785675
# epoch: 13 batch: 19 current batch loss: 0.06415801495313644
# epoch: 13 batch: 20 current batch loss: 0.0718039721250534
# epoch: 13 batch: 21 current batch loss: 0.08194548636674881
# epoch: 13 batch: 22 current batch loss: 0.08233123272657394
# epoch: 13 batch: 23 current batch loss: 0.06534044444561005
# epoch: 13 batch: 24 current batch loss: 0.07796981930732727
# epoch: 13 batch: 25 current batch loss: 0.06242768466472626
# epoch: 13 batch: 26 current batch loss: 0.07254409044981003
# epoch: 13 batch: 27 current batch loss: 0.06959103047847748
# epoch: 13 batch: 28 current batch loss: 0.07309303432703018
# epoch: 13 batch: 29 current batch loss: 0.060776084661483765
# epoch: 14 batch: 0 current batch loss: 0.0831865668296814
# epoch: 14 batch: 1 current batch loss: 0.07902014255523682
# epoch: 14 batch: 2 current batch loss: 0.07767036557197571
# epoch: 14 batch: 3 current batch loss: 0.06562365591526031
# epoch: 14 batch: 4 current batch loss: 0.06508339196443558
# epoch: 14 batch: 5 current batch loss: 0.06674490123987198
# epoch: 14 batch: 6 current batch loss: 0.07855941355228424
# epoch: 14 batch: 7 current batch loss: 0.07541044801473618
# epoch: 14 batch: 8 current batch loss: 0.07933565974235535
# epoch: 14 batch: 9 current batch loss: 0.07324852049350739
# epoch: 14 batch: 10 current batch loss: 0.07051689177751541
# epoch: 14 batch: 11 current batch loss: 0.06393932551145554
# epoch: 14 batch: 12 current batch loss: 0.07610834389925003
# epoch: 14 batch: 13 current batch loss: 0.08196736872196198
# epoch: 14 batch: 14 current batch loss: 0.07169555127620697
# epoch: 14 batch: 15 current batch loss: 0.058882132172584534
# epoch: 14 batch: 16 current batch loss: 0.06324709951877594
# epoch: 14 batch: 17 current batch loss: 0.06857360899448395
# epoch: 14 batch: 18 current batch loss: 0.06646580994129181
# epoch: 14 batch: 19 current batch loss: 0.06695941090583801
# epoch: 14 batch: 20 current batch loss: 0.06244254112243652
# epoch: 14 batch: 21 current batch loss: 0.0785353034734726
# epoch: 14 batch: 22 current batch loss: 0.08804294466972351
# epoch: 14 batch: 23 current batch loss: 0.06580779701471329
# epoch: 14 batch: 24 current batch loss: 0.06836250424385071
# epoch: 14 batch: 25 current batch loss: 0.06632682681083679
# epoch: 14 batch: 26 current batch loss: 0.058846522122621536
# epoch: 14 batch: 27 current batch loss: 0.07381580770015717
# epoch: 14 batch: 28 current batch loss: 0.055851906538009644
# epoch: 14 batch: 29 current batch loss: 0.05817761644721031
# epoch: 15 batch: 0 current batch loss: 0.0662708654999733
# epoch: 15 batch: 1 current batch loss: 0.07866770774126053
# epoch: 15 batch: 2 current batch loss: 0.06564154475927353
# epoch: 15 batch: 3 current batch loss: 0.06047971174120903
# epoch: 15 batch: 4 current batch loss: 0.07098514586687088
# epoch: 15 batch: 5 current batch loss: 0.06082621216773987
# epoch: 15 batch: 6 current batch loss: 0.06963218748569489
# epoch: 15 batch: 7 current batch loss: 0.06425127387046814
# epoch: 15 batch: 8 current batch loss: 0.0620889887213707
# epoch: 15 batch: 9 current batch loss: 0.07022828608751297
# epoch: 15 batch: 10 current batch loss: 0.07599390298128128
# epoch: 15 batch: 11 current batch loss: 0.06482230871915817
# epoch: 15 batch: 12 current batch loss: 0.06725677102804184
# epoch: 15 batch: 13 current batch loss: 0.057611383497714996
# epoch: 15 batch: 14 current batch loss: 0.060465384274721146
# epoch: 15 batch: 15 current batch loss: 0.0701388567686081
# epoch: 15 batch: 16 current batch loss: 0.0744415670633316
# epoch: 15 batch: 17 current batch loss: 0.07002295553684235
# epoch: 15 batch: 18 current batch loss: 0.06609083712100983
# epoch: 15 batch: 19 current batch loss: 0.04615567997097969
# epoch: 15 batch: 20 current batch loss: 0.06765337288379669
# epoch: 15 batch: 21 current batch loss: 0.07060091942548752
# epoch: 15 batch: 22 current batch loss: 0.06802456825971603
# epoch: 15 batch: 23 current batch loss: 0.05143142119050026
# epoch: 15 batch: 24 current batch loss: 0.05486619099974632
# epoch: 15 batch: 25 current batch loss: 0.05921853706240654
# epoch: 15 batch: 26 current batch loss: 0.05257881060242653
# epoch: 15 batch: 27 current batch loss: 0.07378797233104706
# epoch: 15 batch: 28 current batch loss: 0.06673557311296463
# epoch: 15 batch: 29 current batch loss: 0.06584706902503967

# %% [markdown]
# # Testing
# ----------------------

# %%
good = 0
wrong = 0

net.eval()              #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing evaluation
with torch.no_grad():   #it prevents that the net learns during evalution. The gradients are not computed, so this makes it faster, too
    for batch, data in enumerate(testloader): #batches in test are of size 1
        datapoint, label = data

        prediction = net(datapoint.to(device))                  #prediction has values representing the "prevalence" of the corresponding class
        classification = torch.argmax(prediction)    #the class is the index of maximal "prevalence"

        if classification.item() == label.item():
            good += 1
        else:
            wrong += 1

print("accuracy = ", good/(good+wrong))

torch.save(net.state_dict(), "LeNet5_weights.pkl")
# Out:
# accuracy =  0.9809

# %% [markdown]
# # Understanding Kernel Size, Stride and Padding

# %% [markdown]
# ## Task: Designing a Convolutional Neural Network with a Target Receptive Field
#
# Design a convolutional neural network using only 3×3 or 5×5 convolutional layers and 2×2 max-pooling layers without overlap (i.e., with stride 2). Use no padding in any layer. Insert a max-pooling layer after every two or three convolutional layers.
#
# Your goal is to construct an architecture such that the receptive field of each output neuron is approximately 60×60 pixels.
#
# Compute the receptive field size of the final output layer.
#
# Compute the effective stride of the output layer with respect to the input.
#
# Assuming an input image size of 400×400, determine the spatial size of the output feature map.
#
# Q: Where would you locate ReLU layers?
# Q: What if we can't match the desired input size with our architecture?
# Q: Discuss what possible impact padding can have on the network performance.

# %% [markdown]
# # **Homework Assignment – Adversarial Examples**
#
# In this assignment, you will explore how small (invisible to humans) changes to real digits can _fool_ the CNN into misclassifying them, even though the changes are imperceptible to humans.
#
#
#
# ## Task 1 – CNN Dreams: Last Homework Assignment Revisited
#
# Re-run the input optimization process (for NN dreams) from the previous MLP-class homework assignment, but this time using the **LeNet-5 CNN model** we trained in this class.
#
#
# 1. Starting from ten random noise images, optimize the input so that each image is classified with high confidence as one of the digits 0 through 9.
# 2. Include an **L2 penalty** on the input to keep the images visually closer to realistic digits. Use a range of penalty strengths (e.g., $\lambda_{l2}$ = 0, and then 0.01 through 10.0).
# 3. Compare the generated images (with and without L2 penalty) to those generated by the MLP:
#    - Are they more or less readable?
#    - Do they resemble real MNIST digits more closely or less?
#    - Why do you think that happens? Consider the CNN’s inductive biases and architectural properties.
#
# Use `cross_entropy_loss + lambda_l2 * input.pow(2).mean()` as your objective.
#
# Reuse your code: visualize confidence evolution during optimization and generate image grids and (optionally) animations showing how the inputs evolve.
#
#
# ## Task 2 – Adversarial Examples: Fooling LeNet-5
#
# This is the core focus of the assignment.
#
# Using a batch of **real MNIST digits** (e.g., nine examples per class), craft **adversarial examples** by adding subtle, trained noise to the input images. Your goal is to:
#
# - **Keep the human-perceived digit the same** (e.g., a "7" should still look like a "7"),
# - But **cause LeNet-5 to misclassify it** – as every other class different from the original, hence nine examples per class.
#
# ### Objective
# For each image $x$ and its true label $y$, learn a perturbation $\delta$ such that:
#
# - $\text{LeNet5}(x + \delta) = y_{\text{wrong}} $,
# - and $ \|\delta\|_2 $ is as small as possible (penalize large perturbations), to keep $x + \delta$ *look* like $x$ for humans.
#
# ### Optimization
# Use gradient-based optimization on $\delta$ (the noise), while keeping the network weights frozen. Your loss might look like:
#
# ```
# loss = cross_entropy(model(x + delta), target_wrong_class) +
#        lambda_l2 * delta.pow(2).mean()
# ```
#
# Tune the $\lambda_{l2}$ to find the best range.
#
# ### Deliverables for the Second Task
# - Select some best examples, showing the original digit and its (correct) classification and the perturbed digit (hopefully, still looking the same to humans) and how it gets misclassified. Show them side by side.
# - Report:
#   - Success rate of attacks (it doesn't need to be very formal),
#   - Effect of $\lambda_{l2}$ on visibility of the noise and success of misclassification,
#   - Example image grids and confidence plots.
#
#
#
# ## Deliverables for the Homework Assignment
# - A Google Colab notebook with:
#   - Complete implementation for both tasks.
#   - Visualizations and animations (animations are optional but encouraged).
#   - Clear written analysis of your findings.
# - Upload the notebook and results to your GitHub repository for the course.
# - Include a link to the notebook and video (if applicable) in the `README.md`.
# - In the notebook, include “Open in Colab” badge so it can be launched directly.
